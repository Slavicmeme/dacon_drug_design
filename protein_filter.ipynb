# %%
import pandas as pd
# Out:
# Original df shape: (90215, 7)
# Filtered df shape: (70704, 7)

# %%
# CSV 파일 불러오기
csv_name = "train_data_smi"
df = pd.read_csv(csv_name + '.csv')

con_name = "target_protein_wiki"
con = pd.read_csv(con_name + '.csv')

# %%
# Wiki 컬럼에서 값이 "FALSE"인 행들을 필터링하여 Target Name 컬럼 값을 리스트로 저장합니다.
false_list = con[con['Wiki'] == "FALSE"]['Target Name'].tolist()

# %%
# false_list에 있는 Target Name 값들을 df에서 제거합니다.
df_filtered = df[~df['Target Name'].isin(false_list)]

# 필터링된 데이터프레임을 저장하거나 출력합니다.
df_filtered.to_csv('Filtered_' + csv_name + '.csv', index = False)

# %%
# 결과 출력 (필요할 경우)
print(f"Original df shape: {df.shape}")
print(f"Filtered df shape: {df_filtered.shape}")

# %%
len(df_filtered)
# Out:
# 70704

# %%
# 중복된 Smiles 값들을 찾아서 그 수를 계산합니다.
duplicate_smiles_counts = df_filtered.groupby('Smiles')['Target Name'].nunique()

# 중복된 Smiles 값들만 필터링합니다.
duplicate_smiles = duplicate_smiles_counts[duplicate_smiles_counts > 1]

# 결과 출력 (필요할 경우)
print(duplicate_smiles)
# Out:
# Smiles
# Br.COc1cc(OC)cc(N(CCP(=O)(O)O)c2ccc3ncc(-c4cnn(C)c4)nc3c2)c1    2
# Br.NC(=O)c1cnc2[nH]ccc2c1NC1C2CC3CC1CC(O)(C3)C2                 2
# BrC[C@H]1CC[C@H](c2nnn3cnc4[nH]ccc4c23)CC1                      2
# Brc1ccc(-c2nc3ccc(Nc4ncnc5ccccc45)cc3[nH]2)cc1                  2
# Brc1ccc(CN2CCC(c3nnn4cnc5[nH]ccc5c34)CC2)cc1                    2
#                                                                ..
# c1nc2c(N3CCOCC3)nc(-c3ccoc3)nc2[nH]1                            2
# c1nc2c(N3CCOCC3)nc(-c3ccsc3)nc2[nH]1                            3
# c1nc2c(NC3CCCCC3)nc(Nc3ccc(N4CCOCC4)cc3)nc2[nH]1                2
# c1ncc(-c2cc3cnc(Nc4ccc(CN5CCNCC5)cn4)nc3n2C2CCCC2)o1            2
# c1ncc(-c2cc3cnc(Nc4ccc(N5CCNCC5)cn4)nc3n2C2CCCC2)o1             2
# Name: Target Name, Length: 11689, dtype: int64

# %%
# 중복된 Smiles 값들을 찾아서 그 수를 계산합니다.
duplicate_smiles_counts = df_filtered.groupby('Smiles')['Target Name'].nunique()

# 중복된 Smiles 값들만 필터링합니다.
duplicate_smiles = duplicate_smiles_counts[duplicate_smiles_counts > 1]

# 중복된 Smiles 값의 수를 출력합니다.
print(f"Number of duplicate Smiles: {len(duplicate_smiles)}")
# Out:
# Number of duplicate Smiles: 11689

# %%
# 중복된 Smiles 값을 가진 행들을 추출합니다.
duplicate_smiles = df_filtered[df_filtered.duplicated('Smiles', keep=False)]

# 중복된 Smiles 값을 기준으로 그룹화하고, 각 그룹에 속하는 Target Name들을 리스트로 묶어 출력합니다.
grouped_duplicates = duplicate_smiles.groupby('Smiles')['Target Name'].apply(lambda x: list(x)).reset_index()

# 결과 출력
for index, row in grouped_duplicates.iterrows():
    print(f"Smiles: {row['Smiles']}")
    print(f"Target Names: {row['Target Name']}")
    print("-" * 50)

print(duplicate_smiles.shape)
# Out:
# Smiles: Br.COc1cc(OC)cc(N(CCP(=O)(O)O)c2ccc3ncc(-c4cnn(C)c4)nc3c2)c1
# Target Names: ['Fibroblast growth factor receptor 4', 'Vascular endothelial growth factor receptor 2']
# --------------------------------------------------
# Smiles: Br.NC(=O)c1cnc2[nH]ccc2c1NC1C2CC3CC1CC(O)(C3)C2
# Target Names: ['Tyrosine-protein kinase JAK2', 'Tyrosine-protein kinase JAK3']
# --------------------------------------------------
# Smiles: BrC[C@H]1CC[C@H](c2nnn3cnc4[nH]ccc4c23)CC1
# Target Names: ['Tyrosine-protein kinase JAK2', 'Tyrosine-protein kinase JAK3']
# --------------------------------------------------
# Smiles: Brc1ccc(-c2nc3ccc(Nc4ncnc5ccccc45)cc3[nH]2)cc1
# Target Names: ['Hepatocyte growth factor receptor', 'Vascular endothelial growth factor receptor 2']
# --------------------------------------------------
# Smiles: Brc1ccc(CN2CCC(c3nnn4cnc5[nH]ccc5c34)CC2)cc1
# Target Names: ['Tyrosine-protein kinase JAK2', 'Tyrosine-protein kinase JAK3']
# ...

# %%
grouped_duplicates.to_csv("grouped_duplicates.csv", index=False)
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 grouped_duplicates.to_csv("grouped_duplicates.csv", index=False)
#
# File c:\Users\stu83\miniconda3\envs\dacon\Lib\site-packages\pandas\util\_decorators.py:333, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     327 if len(args) > num_allow_args:
#     328     warnings.warn(
#     329         msg.format(arguments=_format_argument_list(allow_args)),
#     330         FutureWarning,
#     331         stacklevel=find_stack_level(),
#     332     )
# --> 333 return func(*args, **kwargs)
#
# ...
