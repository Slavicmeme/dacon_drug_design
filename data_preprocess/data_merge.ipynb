# %%
import pandas as pd
import os
import numpy as np

# %%
data_dir_path = os.path.join('train_data/original_data')

# %%
# 폴더 안의 모든 파일명을 출력
file_names = os.listdir(data_dir_path)

# 출력
for file_name in file_names:
    print(file_name)
# Out:
# c-Ret.tsv
# Macrophage-stimulating protein receptor.tsv
# CDKs-7.tsv
# ATM.tsv
# Plasma kallikrein.tsv
# PI3-kinase p110-alpha subunit.tsv
# Signal transducer and activator of transcription 3.tsv
# PI3-kinase p110-alphap85-alpha.tsv
# ROCK2.tsv
# Tyrosine-protein kinase JAK2.tsv
# Vascular endothelial growth factor receptor.tsv
# Neurotrophic tyrosine kinase receptor type 2.tsv
# b-Raf.tsv
# Tyrosine-protein kinase TXK.tsv
# PI3-kinase p110-delta subunit.tsv
# Tyrosine-protein kinase ABL.tsv
# mTOR.tsv
# PI3K p110 betap85 alpha.tsv
# Dual specificity protein kinase TTK.tsv
# Tyrosine-protein kinase ITKTSK.tsv
# PI3-kinase p110-deltap85-alpha.tsv
# ATP-dependent Clp protease proteolytic subunit.tsv
# Choline kinase alpha.tsv
# Tyrosine-protein kinase TEC.tsv
# Tyrosine-protein kinase receptor FLT3.tsv
# CDKs-1.tsv
# Tankyrase 12.tsv
# train.csv
# ALK.tsv
# Ephrin type-B receptor 4.tsv
# Serinethreonine-protein kinase Chk1.tsv
# Replicase polyprotein 1ab.tsv
# ...

# %%
tsv_file_path1 = os.path.join(data_dir_path, 'c-Ret.tsv')
tsv_file_path2 = os.path.join(data_dir_path, 'Macrophage-stimulating protein receptor.tsv')
tsv_file_path3 = os.path.join(data_dir_path, 'CDKs-7.tsv')
tsv_file_path4 = os.path.join(data_dir_path, 'ATM.tsv')
tsv_file_path5 = os.path.join(data_dir_path, 'Plasma kallikrein.tsv')
tsv_file_path6 = os.path.join(data_dir_path, 'PI3-kinase p110-alpha subunit.tsv')
tsv_file_path7 = os.path.join(data_dir_path, 'Signal transducer and activator of transcription 3.tsv')
tsv_file_path8 = os.path.join(data_dir_path, 'PI3-kinase p110-alphap85-alpha.tsv')
tsv_file_path9 = os.path.join(data_dir_path, 'ROCK2.tsv')
tsv_file_path10 = os.path.join(data_dir_path, 'Tyrosine-protein kinase JAK2.tsv')

tsv_file_path11 = os.path.join(data_dir_path, 'Vascular endothelial growth factor receptor.tsv')
tsv_file_path12 = os.path.join(data_dir_path, 'Neurotrophic tyrosine kinase receptor type 2.tsv')
tsv_file_path13 = os.path.join(data_dir_path, 'b-Raf.tsv')
tsv_file_path14 = os.path.join(data_dir_path, 'Tyrosine-protein kinase TXK.tsv')
tsv_file_path15 = os.path.join(data_dir_path, 'PI3-kinase p110-delta subunit.tsv')
tsv_file_path16 = os.path.join(data_dir_path, 'Tyrosine-protein kinase ABL.tsv')
tsv_file_path17 = os.path.join(data_dir_path, 'mTOR.tsv')
tsv_file_path18 = os.path.join(data_dir_path, 'PI3K p110 betap85 alpha.tsv')
tsv_file_path19 = os.path.join(data_dir_path, 'Dual specificity protein kinase TTK.tsv')
tsv_file_path20 = os.path.join(data_dir_path, 'Tyrosine-protein kinase ITKTSK.tsv')

tsv_file_path21 = os.path.join(data_dir_path, 'PI3-kinase p110-deltap85-alpha.tsv')
tsv_file_path22 = os.path.join(data_dir_path, 'ATP-dependent Clp protease proteolytic subunit.tsv')
tsv_file_path23 = os.path.join(data_dir_path, 'Choline kinase alpha.tsv')
tsv_file_path24 = os.path.join(data_dir_path, 'Tyrosine-protein kinase TEC.tsv')
tsv_file_path25 = os.path.join(data_dir_path, 'Tyrosine-protein kinase receptor FLT3.tsv')
tsv_file_path26 = os.path.join(data_dir_path, 'CDKs-1.tsv')
tsv_file_path27 = os.path.join(data_dir_path, 'Tankyrase 12.tsv')
tsv_file_path28 = os.path.join(data_dir_path, 'train.csv')
tsv_file_path29 = os.path.join(data_dir_path, 'ALK.tsv')
tsv_file_path30 = os.path.join(data_dir_path, 'Ephrin type-B receptor 4.tsv')

tsv_file_path31 = os.path.join(data_dir_path, 'Serinethreonine-protein kinase Chk1.tsv')
tsv_file_path32 = os.path.join(data_dir_path, 'Replicase polyprotein 1ab.tsv')
tsv_file_path33 = os.path.join(data_dir_path, 'Cyclin-dependent kinase 1cyclin B1.tsv')
tsv_file_path34 = os.path.join(data_dir_path, 'CDKs-5.tsv')
tsv_file_path35 = os.path.join(data_dir_path, 'Rho kinase.tsv')
tsv_file_path36 = os.path.join(data_dir_path, 'Thymidine kinase, cytosolic.tsv')
tsv_file_path37 = os.path.join(data_dir_path, 'Interleukin-1 receptor-associated kinase 4.tsv')
tsv_file_path38 = os.path.join(data_dir_path, 'Casein kinase I epsilon.tsv')
tsv_file_path39 = os.path.join(data_dir_path, 'JAK.tsv')
tsv_file_path40 = os.path.join(data_dir_path, 'Tyrosine-protein kinase SRC.tsv')

tsv_file_path41 = os.path.join(data_dir_path, 'Akt.tsv')
tsv_file_path42 = os.path.join(data_dir_path, 'Thymidine kinase.tsv')
tsv_file_path43 = os.path.join(data_dir_path, 'Serinethreonine-protein kinase PLK3.tsv')
tsv_file_path44 = os.path.join(data_dir_path, 'Focal adhesion kinase 1.tsv')
tsv_file_path45 = os.path.join(data_dir_path, 'Interleukin-1 receptor-associated kinase 3.tsv')
tsv_file_path46 = os.path.join(data_dir_path, 'SRC.tsv')
tsv_file_path47 = os.path.join(data_dir_path, 'Tyrosine-protein kinase BTK.tsv')
tsv_file_path48 = os.path.join(data_dir_path, 'DNA-directed RNA polymerase beta chain.tsv')
tsv_file_path49 = os.path.join(data_dir_path, 'Nerve growth factor receptor Trk-A.tsv')
tsv_file_path50 = os.path.join(data_dir_path, 'PI3-kinase p110-beta subunit.tsv')


tsv_file_path51 = os.path.join(data_dir_path, 'Serinethreonine-protein kinase PLK2.tsv')
tsv_file_path52 = os.path.join(data_dir_path, 'Pancreatic triacylglycerol lipase.tsv')
tsv_file_path53 = os.path.join(data_dir_path, 'Fibroblast growth factor receptor 4.tsv')
tsv_file_path54 = os.path.join(data_dir_path, 'CDKs-2.tsv')
tsv_file_path55 = os.path.join(data_dir_path, 'Hepatocyte growth factor receptor.tsv')
tsv_file_path56 = os.path.join(data_dir_path, 'Vascular endothelial growth factor receptor 2.tsv')
tsv_file_path57 = os.path.join(data_dir_path, 'Aurora-A.tsv')
tsv_file_path58 = os.path.join(data_dir_path, 'CDKs-9.tsv')
tsv_file_path59 = os.path.join(data_dir_path, 'E3 ubiquitin-protein ligase TRIM33.tsv')
tsv_file_path60 = os.path.join(data_dir_path, 'Serinethreonine-protein kinase B-raf.tsv')


tsv_file_path61 = os.path.join(data_dir_path, 'Phosphatidylinositol 3-kinase catalytic subunit type 3.tsv')
tsv_file_path62 = os.path.join(data_dir_path, 'b-Raf2.tsv')
tsv_file_path63 = os.path.join(data_dir_path, 'Tyrosine-protein kinase receptor TYRO3.tsv')
tsv_file_path64 = os.path.join(data_dir_path, 'Serinethreonine-protein kinase MST2.tsv')
tsv_file_path65 = os.path.join(data_dir_path, 'Tyrosine-protein kinase receptor RET.tsv')
tsv_file_path66 = os.path.join(data_dir_path, 'Tyrosine-protein kinase BMX.tsv')
tsv_file_path67 = os.path.join(data_dir_path, 'Kinesin-1 heavy chain Tyrosine-protein kinase receptor RET.tsv')
tsv_file_path68 = os.path.join(data_dir_path, 'JAK2.tsv')
tsv_file_path69 = os.path.join(data_dir_path, 'Casein kinase I delta.tsv')
tsv_file_path70 = os.path.join(data_dir_path, 'Fibroblast growth factor receptor.tsv')

tsv_file_path71 = os.path.join(data_dir_path, 'Serinethreonine-protein kinase PLK1.tsv')
tsv_file_path72 = os.path.join(data_dir_path, 'Tankyrase-2.tsv')
tsv_file_path73 = os.path.join(data_dir_path, 'Serinethreonine-protein kinase PLK4.tsv')
tsv_file_path74 = os.path.join(data_dir_path, '6-phospho-1-fructokinase, putative.tsv')
tsv_file_path75 = os.path.join(data_dir_path, 'erbB-2.tsv')
tsv_file_path76 = os.path.join(data_dir_path, 'Akt2.tsv')
tsv_file_path77 = os.path.join(data_dir_path, 'Interleukin-1 receptor-associated kinase 1.tsv')
tsv_file_path78 = os.path.join(data_dir_path, 'Eukaryotic translation initiation factor 2-alpha kinase 3.tsv')
tsv_file_path79 = os.path.join(data_dir_path, 'Cyclin-dependent kinase 1cyclin B.tsv')
tsv_file_path80 = os.path.join(data_dir_path, 'Thymidine kinase, mitochondrial.tsv')

tsv_file_path81 = os.path.join(data_dir_path, 'Stem cell growth factor receptor.tsv')
tsv_file_path82 = os.path.join(data_dir_path, 'Abl.tsv')
tsv_file_path83 = os.path.join(data_dir_path, 'Phosphoglycerate kinase.tsv')
tsv_file_path84 = os.path.join(data_dir_path, 'Tyrosine-protein kinase BRK.tsv')
tsv_file_path85 = os.path.join(data_dir_path, 'Serinethreonine-protein kinase mTOR.tsv')
tsv_file_path86 = os.path.join(data_dir_path, 'Akt3.tsv')
tsv_file_path87 = os.path.join(data_dir_path, 'PI3-kinase p110-gamma subunit.tsv')

# TSV 데이터 읽기
tsv_data1 = pd.read_csv(tsv_file_path1, delimiter='\t')
tsv_data2 = pd.read_csv(tsv_file_path2, delimiter='\t')
tsv_data3 = pd.read_csv(tsv_file_path3, delimiter='\t')
tsv_data4 = pd.read_csv(tsv_file_path4, delimiter='\t')
tsv_data5 = pd.read_csv(tsv_file_path5, delimiter='\t')
tsv_data6 = pd.read_csv(tsv_file_path6, delimiter='\t')
tsv_data7 = pd.read_csv(tsv_file_path7, delimiter='\t')
tsv_data8 = pd.read_csv(tsv_file_path8, delimiter='\t')
tsv_data9 = pd.read_csv(tsv_file_path9, delimiter='\t')
tsv_data10 = pd.read_csv(tsv_file_path10, delimiter='\t')

tsv_data11 = pd.read_csv(tsv_file_path11, delimiter='\t')
tsv_data12 = pd.read_csv(tsv_file_path12, delimiter='\t')
tsv_data13 = pd.read_csv(tsv_file_path13, delimiter='\t')
tsv_data14 = pd.read_csv(tsv_file_path14, delimiter='\t')
tsv_data15 = pd.read_csv(tsv_file_path15, delimiter='\t')
tsv_data16 = pd.read_csv(tsv_file_path16, delimiter='\t')
tsv_data17 = pd.read_csv(tsv_file_path17, delimiter='\t')
tsv_data18 = pd.read_csv(tsv_file_path18, delimiter='\t')
tsv_data19 = pd.read_csv(tsv_file_path19, delimiter='\t')
tsv_data20 = pd.read_csv(tsv_file_path20, delimiter='\t')

tsv_data21 = pd.read_csv(tsv_file_path21, delimiter='\t')
tsv_data22 = pd.read_csv(tsv_file_path22, delimiter='\t')
tsv_data23 = pd.read_csv(tsv_file_path23, delimiter='\t')
tsv_data24 = pd.read_csv(tsv_file_path24, delimiter='\t')
tsv_data25 = pd.read_csv(tsv_file_path25, delimiter='\t')
tsv_data26 = pd.read_csv(tsv_file_path26, delimiter='\t')
tsv_data27 = pd.read_csv(tsv_file_path27, delimiter='\t')
tsv_data28 = pd.read_csv(tsv_file_path28, delimiter='\t')
tsv_data29 = pd.read_csv(tsv_file_path29, delimiter='\t')
tsv_data30 = pd.read_csv(tsv_file_path30, delimiter='\t')

tsv_data31 = pd.read_csv(tsv_file_path31, delimiter='\t')
tsv_data32 = pd.read_csv(tsv_file_path32, delimiter='\t')
tsv_data33 = pd.read_csv(tsv_file_path33, delimiter='\t')
tsv_data34 = pd.read_csv(tsv_file_path34, delimiter='\t')
tsv_data35 = pd.read_csv(tsv_file_path35, delimiter='\t')
tsv_data36 = pd.read_csv(tsv_file_path36, delimiter='\t')
tsv_data37 = pd.read_csv(tsv_file_path37, delimiter='\t')
tsv_data38 = pd.read_csv(tsv_file_path38, delimiter='\t')
tsv_data39 = pd.read_csv(tsv_file_path39, delimiter='\t')

tsv_data40 = pd.read_csv(tsv_file_path40, delimiter='\t')
tsv_data41 = pd.read_csv(tsv_file_path41, delimiter='\t')
tsv_data42 = pd.read_csv(tsv_file_path42, delimiter='\t')
tsv_data43 = pd.read_csv(tsv_file_path43, delimiter='\t')
tsv_data44 = pd.read_csv(tsv_file_path44, delimiter='\t')
tsv_data45 = pd.read_csv(tsv_file_path45, delimiter='\t')
tsv_data46 = pd.read_csv(tsv_file_path46, delimiter='\t')
tsv_data47 = pd.read_csv(tsv_file_path47, delimiter='\t')
tsv_data48 = pd.read_csv(tsv_file_path48, delimiter='\t')
tsv_data49 = pd.read_csv(tsv_file_path49, delimiter='\t')
tsv_data50 = pd.read_csv(tsv_file_path50, delimiter='\t')


tsv_data51 = pd.read_csv(tsv_file_path51, delimiter='\t')
tsv_data52 = pd.read_csv(tsv_file_path52, delimiter='\t')
tsv_data53 = pd.read_csv(tsv_file_path53, delimiter='\t')
tsv_data54 = pd.read_csv(tsv_file_path54, delimiter='\t')
tsv_data55 = pd.read_csv(tsv_file_path55, delimiter='\t')
tsv_data56 = pd.read_csv(tsv_file_path56, delimiter='\t')
tsv_data57 = pd.read_csv(tsv_file_path57, delimiter='\t')
tsv_data58 = pd.read_csv(tsv_file_path58, delimiter='\t')
tsv_data59 = pd.read_csv(tsv_file_path59, delimiter='\t')
tsv_data60 = pd.read_csv(tsv_file_path60, delimiter='\t')

tsv_data61 = pd.read_csv(tsv_file_path61, delimiter='\t')
tsv_data62 = pd.read_csv(tsv_file_path62, delimiter='\t')
tsv_data63 = pd.read_csv(tsv_file_path63, delimiter='\t')
tsv_data64 = pd.read_csv(tsv_file_path64, delimiter='\t')
tsv_data65 = pd.read_csv(tsv_file_path65, delimiter='\t')
tsv_data66 = pd.read_csv(tsv_file_path66, delimiter='\t')
tsv_data67 = pd.read_csv(tsv_file_path67, delimiter='\t')
tsv_data68 = pd.read_csv(tsv_file_path68, delimiter='\t')
tsv_data69 = pd.read_csv(tsv_file_path69, delimiter='\t')
tsv_data70 = pd.read_csv(tsv_file_path70, delimiter='\t')


tsv_data71 = pd.read_csv(tsv_file_path71, delimiter='\t')
tsv_data72 = pd.read_csv(tsv_file_path72, delimiter='\t')
tsv_data73 = pd.read_csv(tsv_file_path73, delimiter='\t')
tsv_data74 = pd.read_csv(tsv_file_path74, delimiter='\t')
tsv_data75 = pd.read_csv(tsv_file_path75, delimiter='\t')
tsv_data76 = pd.read_csv(tsv_file_path76, delimiter='\t')
tsv_data77 = pd.read_csv(tsv_file_path77, delimiter='\t')
tsv_data78 = pd.read_csv(tsv_file_path78, delimiter='\t')
tsv_data79 = pd.read_csv(tsv_file_path79, delimiter='\t')
tsv_data80 = pd.read_csv(tsv_file_path80, delimiter='\t')

tsv_data81 = pd.read_csv(tsv_file_path81, delimiter='\t')
tsv_data82 = pd.read_csv(tsv_file_path82, delimiter='\t')
tsv_data83 = pd.read_csv(tsv_file_path83, delimiter='\t')
tsv_data84 = pd.read_csv(tsv_file_path84, delimiter='\t')
tsv_data85 = pd.read_csv(tsv_file_path85, delimiter='\t')
tsv_data86 = pd.read_csv(tsv_file_path86, delimiter='\t')
tsv_data87 = pd.read_csv(tsv_file_path87, delimiter='\t')



# 데이터프레임 형태 출력
print(f"c-Ret.tsv: {tsv_data1.shape}")
print(f"Macrophage-stimulating protein receptor.tsv: {tsv_data2.shape}")
print(f"CDKs-7.tsv: {tsv_data3.shape}")
print(f"ATM.tsv: {tsv_data4.shape}")
print(f"Plasma kallikrein.tsv: {tsv_data5.shape}")
print(f"PI3-kinase p110-alpha subunit.tsv: {tsv_data6.shape}")
print(f"Signal transducer and activator of transcription 3.tsv: {tsv_data7.shape}")
print(f"PI3-kinase p110-alphap85-alpha.tsv: {tsv_data8.shape}")
print(f"ROCK2.tsv: {tsv_data9.shape}")
print(f"Tyrosine-protein kinase JAK2.tsv: {tsv_data10.shape}")
print(f"Vascular endothelial growth factor receptor.tsv: {tsv_data11.shape}")
print(f"Neurotrophic tyrosine kinase receptor type 2.tsv: {tsv_data12.shape}")
print(f"b-Raf.tsv: {tsv_data13.shape}")
print(f"Tyrosine-protein kinase TXK.tsv: {tsv_data14.shape}")
print(f"PI3-kinase p110-delta subunit.tsv: {tsv_data15.shape}")
print(f"Tyrosine-protein kinase ABL.tsv: {tsv_data16.shape}")
print(f"mTOR.tsv: {tsv_data17.shape}")
print(f"PI3K p110 betap85 alpha.tsv: {tsv_data18.shape}")
print(f"Dual specificity protein kinase TTK.tsv: {tsv_data19.shape}")
print(f"Tyrosine-protein kinase ITKTSK.tsv: {tsv_data20.shape}")
print(f"PI3-kinase p110-deltap85-alpha.tsv: {tsv_data21.shape}")
print(f"ATP-dependent Clp protease proteolytic subunit.tsv: {tsv_data22.shape}")
print(f"Choline kinase alpha.tsv: {tsv_data23.shape}")
print(f"Tyrosine-protein kinase TEC.tsv: {tsv_data24.shape}")
print(f"Tyrosine-protein kinase receptor FLT3.tsv: {tsv_data25.shape}")
print(f"CDKs-1.tsv: {tsv_data26.shape}")
print(f"Tankyrase 12.tsv: {tsv_data27.shape}")
print(f"train.csv: {tsv_data28.shape}")
print(f"ALK.tsv: {tsv_data29.shape}")
print(f"Ephrin type-B receptor 4.tsv: {tsv_data30.shape}")
print(f"Serinethreonine-protein kinase Chk1.tsv: {tsv_data31.shape}")
print(f"Replicase polyprotein 1ab.tsv: {tsv_data32.shape}")
print(f"Cyclin-dependent kinase 1cyclin B1.tsv: {tsv_data33.shape}")
print(f"CDKs-5.tsv: {tsv_data34.shape}")
print(f"Rho kinase.tsv: {tsv_data35.shape}")
print(f"Thymidine kinase, cytosolic.tsv: {tsv_data36.shape}")
print(f"Interleukin-1 receptor-associated kinase 4.tsv: {tsv_data37.shape}")
print(f"Casein kinase I epsilon.tsv: {tsv_data38.shape}")
print(f"JAK.tsv: {tsv_data39.shape}")

print(f"Tyrosine-protein kinase SRC.tsv: {tsv_data40.shape}")
print(f"Akt.tsv: {tsv_data41.shape}")
print(f"Thymidine kinase.tsv: {tsv_data42.shape}")
print(f"Serinethreonine-protein kinase PLK3.tsv: {tsv_data43.shape}")
print(f"Focal adhesion kinase 1.tsv: {tsv_data44.shape}")
print(f"Interleukin-1 receptor-associated kinase 3.tsv: {tsv_data45.shape}")
print(f"SRC.tsv: {tsv_data46.shape}")
print(f"Tyrosine-protein kinase BTK.tsv: {tsv_data47.shape}")
print(f"DNA-directed RNA polymerase beta chain.tsv: {tsv_data48.shape}")
print(f"Nerve growth factor receptor Trk-A.tsv: {tsv_data49.shape}")
print(f"PI3-kinase p110-beta subunit.tsv: {tsv_data50.shape}")
print(f"Serinethreonine-protein kinase PLK2.tsv: {tsv_data51.shape}")
print(f"Pancreatic triacylglycerol lipase.tsv: {tsv_data52.shape}")
print(f"Fibroblast growth factor receptor 4.tsv: {tsv_data53.shape}")
print(f"CDKs-2.tsv: {tsv_data54.shape}")
print(f"Hepatocyte growth factor receptor.tsv: {tsv_data55.shape}")
print(f"Vascular endothelial growth factor receptor 2.tsv: {tsv_data56.shape}")
print(f"Aurora-A.tsv: {tsv_data57.shape}")
print(f"CDKs-9.tsv: {tsv_data58.shape}")
print(f"E3 ubiquitin-protein ligase TRIM33.tsv: {tsv_data59.shape}")
print(f"Serinethreonine-protein kinase B-raf.tsv: {tsv_data60.shape}")
print(f"Phosphatidylinositol 3-kinase catalytic subunit type 3.tsv: {tsv_data61.shape}")
print(f"b-Raf2.tsv: {tsv_data62.shape}")
print(f"Tyrosine-protein kinase receptor TYRO3.tsv: {tsv_data63.shape}")
print(f"Serinethreonine-protein kinase MST2.tsv: {tsv_data64.shape}")
print(f"Tyrosine-protein kinase receptor RET.tsv: {tsv_data65.shape}")
print(f"Tyrosine-protein kinase BMX.tsv: {tsv_data66.shape}")
print(f"Kinesin-1 heavy chain Tyrosine-protein kinase receptor RET.tsv: {tsv_data67.shape}")
print(f"JAK2.tsv: {tsv_data68.shape}")
print(f"Casein kinase I delta.tsv: {tsv_data69.shape}")
print(f"Fibroblast growth factor receptor.tsv: {tsv_data70.shape}")
print(f"Serinethreonine-protein kinase PLK1.tsv: {tsv_data71.shape}")
print(f"Tankyrase-2.tsv: {tsv_data72.shape}")
print(f"Serinethreonine-protein kinase PLK4.tsv: {tsv_data73.shape}")
print(f"6-phospho-1-fructokinase, putative.tsv: {tsv_data74.shape}")
print(f"erbB-2.tsv: {tsv_data75.shape}")
print(f"Akt2.tsv: {tsv_data76.shape}")
print(f"Interleukin-1 receptor-associated kinase 1.tsv: {tsv_data77.shape}")
print(f"Eukaryotic translation initiation factor 2-alpha kinase 3.tsv: {tsv_data78.shape}")
print(f"Cyclin-dependent kinase 1cyclin B.tsv: {tsv_data79.shape}")
print(f"Thymidine kinase, mitochondrial.tsv: {tsv_data80.shape}")
print(f"Stem cell growth factor receptor.tsv: {tsv_data81.shape}")
print(f"Abl.tsv: {tsv_data82.shape}")
print(f"Phosphoglycerate kinase.tsv: {tsv_data83.shape}")
print(f"Tyrosine-protein kinase BRK.tsv: {tsv_data84.shape}")
print(f"Serinethreonine-protein kinase mTOR.tsv: {tsv_data85.shape}")
print(f"Akt3.tsv: {tsv_data86.shape}")
print(f"PI3-kinase p110-gamma subunit.tsv: {tsv_data87.shape}")
# Out:
# c-Ret.tsv: (1218, 47)
# Macrophage-stimulating protein receptor.tsv: (191, 47)
# CDKs-7.tsv: (389, 47)
# ATM.tsv: (617, 47)
# Plasma kallikrein.tsv: (1108, 47)
# PI3-kinase p110-alpha subunit.tsv: (6876, 47)
# Signal transducer and activator of transcription 3.tsv: (1224, 47)
# PI3-kinase p110-alphap85-alpha.tsv: (1461, 47)
# ROCK2.tsv: (2811, 47)
# Tyrosine-protein kinase JAK2.tsv: (7657, 47)
# Vascular endothelial growth factor receptor.tsv: (243, 47)
# Neurotrophic tyrosine kinase receptor type 2.tsv: (585, 47)
# b-Raf.tsv: (6962, 47)
# Tyrosine-protein kinase TXK.tsv: (110, 47)
# PI3-kinase p110-delta subunit.tsv: (4708, 47)
# Tyrosine-protein kinase ABL.tsv: (3151, 47)
# mTOR.tsv: (5178, 47)
# PI3K p110 betap85 alpha.tsv: (769, 47)
# Dual specificity protein kinase TTK.tsv: (1406, 47)
# Tyrosine-protein kinase ITKTSK.tsv: (1260, 47)
# PI3-kinase p110-deltap85-alpha.tsv: (1297, 47)
# ATP-dependent Clp protease proteolytic subunit.tsv: (107, 47)
# ...

# %%
tsv_file_paths = [
    os.path.join(data_dir_path, 'c-Ret.tsv'),
    os.path.join(data_dir_path, 'Macrophage-stimulating protein receptor.tsv'),
    os.path.join(data_dir_path, 'CDKs-7.tsv'),
    os.path.join(data_dir_path, 'ATM.tsv'),
    os.path.join(data_dir_path, 'Plasma kallikrein.tsv'),
    os.path.join(data_dir_path, 'PI3-kinase p110-alpha subunit.tsv'),
    os.path.join(data_dir_path, 'Signal transducer and activator of transcription 3.tsv'),
    os.path.join(data_dir_path, 'PI3-kinase p110-alphap85-alpha.tsv'),
    os.path.join(data_dir_path, 'ROCK2.tsv'),
    os.path.join(data_dir_path, 'Tyrosine-protein kinase JAK2.tsv'),
    os.path.join(data_dir_path, 'Vascular endothelial growth factor receptor.tsv'),
    os.path.join(data_dir_path, 'Neurotrophic tyrosine kinase receptor type 2.tsv'),
    os.path.join(data_dir_path, 'b-Raf.tsv'),
    os.path.join(data_dir_path, 'Tyrosine-protein kinase TXK.tsv'),
    os.path.join(data_dir_path, 'PI3-kinase p110-delta subunit.tsv'),
    os.path.join(data_dir_path, 'Tyrosine-protein kinase ABL.tsv'),
    os.path.join(data_dir_path, 'mTOR.tsv'),
    os.path.join(data_dir_path, 'PI3K p110 betap85 alpha.tsv'),
    os.path.join(data_dir_path, 'Dual specificity protein kinase TTK.tsv'),
    os.path.join(data_dir_path, 'Tyrosine-protein kinase ITKTSK.tsv'),
    os.path.join(data_dir_path, 'PI3-kinase p110-deltap85-alpha.tsv'),
    os.path.join(data_dir_path, 'ATP-dependent Clp protease proteolytic subunit.tsv'),
    os.path.join(data_dir_path, 'Choline kinase alpha.tsv'),
    os.path.join(data_dir_path, 'Tyrosine-protein kinase TEC.tsv'),
    os.path.join(data_dir_path, 'Tyrosine-protein kinase receptor FLT3.tsv'),
    os.path.join(data_dir_path, 'CDKs-1.tsv'),
    os.path.join(data_dir_path, 'Tankyrase 12.tsv'),
    os.path.join(data_dir_path, 'ALK.tsv'),
    os.path.join(data_dir_path, 'Ephrin type-B receptor 4.tsv'),
    os.path.join(data_dir_path, 'Serinethreonine-protein kinase Chk1.tsv'),
    os.path.join(data_dir_path, 'Replicase polyprotein 1ab.tsv'),
    os.path.join(data_dir_path, 'Cyclin-dependent kinase 1cyclin B1.tsv'),
    os.path.join(data_dir_path, 'CDKs-5.tsv'),
    os.path.join(data_dir_path, 'Rho kinase.tsv'),
    os.path.join(data_dir_path, 'Thymidine kinase, cytosolic.tsv'),
    os.path.join(data_dir_path, 'Interleukin-1 receptor-associated kinase 4.tsv'),
    os.path.join(data_dir_path, 'Casein kinase I epsilon.tsv'),
    os.path.join(data_dir_path, 'JAK.tsv'),
    os.path.join(data_dir_path, 'Epidermal growth factor receptor erbB1.tsv'),
    os.path.join(data_dir_path, 'Tyrosine-protein kinase SRC.tsv'),
    os.path.join(data_dir_path, 'Akt.tsv'),
    os.path.join(data_dir_path, 'Thymidine kinase.tsv'),
    os.path.join(data_dir_path, 'Serinethreonine-protein kinase PLK3.tsv'),
    os.path.join(data_dir_path, 'Focal adhesion kinase 1.tsv'),
    os.path.join(data_dir_path, 'Interleukin-1 receptor-associated kinase 3.tsv'),
    os.path.join(data_dir_path, 'SRC.tsv'),
    os.path.join(data_dir_path, 'Tyrosine-protein kinase BTK.tsv'),
    os.path.join(data_dir_path, 'DNA-directed RNA polymerase beta chain.tsv'),
    os.path.join(data_dir_path, 'Nerve growth factor receptor Trk-A.tsv'),
    os.path.join(data_dir_path, 'PI3-kinase p110-beta subunit.tsv'),
    os.path.join(data_dir_path, 'Serinethreonine-protein kinase PLK2.tsv'),
    os.path.join(data_dir_path, 'Pancreatic triacylglycerol lipase.tsv'),
    os.path.join(data_dir_path, 'Fibroblast growth factor receptor 4.tsv'),
    os.path.join(data_dir_path, 'CDKs-2.tsv'),
    os.path.join(data_dir_path, 'Hepatocyte growth factor receptor.tsv'),
    os.path.join(data_dir_path, 'Vascular endothelial growth factor receptor 2.tsv'),
    os.path.join(data_dir_path, 'Aurora-A.tsv'),
    os.path.join(data_dir_path, 'CDKs-9.tsv'),
    os.path.join(data_dir_path, 'E3 ubiquitin-protein ligase TRIM33.tsv'),
    os.path.join(data_dir_path, 'Serinethreonine-protein kinase B-raf.tsv'),
    os.path.join(data_dir_path, 'Phosphatidylinositol 3-kinase catalytic subunit type 3.tsv'),
    os.path.join(data_dir_path, 'b-Raf2.tsv'),
    os.path.join(data_dir_path, 'Tyrosine-protein kinase receptor TYRO3.tsv'),
    os.path.join(data_dir_path, 'Serinethreonine-protein kinase MST2.tsv'),
    os.path.join(data_dir_path, 'Tyrosine-protein kinase receptor RET.tsv'),
    os.path.join(data_dir_path, 'Tyrosine-protein kinase BMX.tsv'),
    os.path.join(data_dir_path, 'Kinesin-1 heavy chain Tyrosine-protein kinase receptor RET.tsv'),
    os.path.join(data_dir_path, 'JAK2.tsv'),
    os.path.join(data_dir_path, 'Casein kinase I delta.tsv'),
    os.path.join(data_dir_path, 'Fibroblast growth factor receptor.tsv'),
    os.path.join(data_dir_path, 'Serinethreonine-protein kinase PLK1.tsv'),
    os.path.join(data_dir_path, 'Tankyrase-2.tsv'),
    os.path.join(data_dir_path, 'Serinethreonine-protein kinase PLK4.tsv'),
    os.path.join(data_dir_path, '6-phospho-1-fructokinase, putative.tsv'),
    os.path.join(data_dir_path, 'erbB-2.tsv'),
    os.path.join(data_dir_path, 'Akt2.tsv'),
    os.path.join(data_dir_path, 'Interleukin-1 receptor-associated kinase 1.tsv'),
    os.path.join(data_dir_path, 'Eukaryotic translation initiation factor 2-alpha kinase 3.tsv'),
    os.path.join(data_dir_path, 'Cyclin-dependent kinase 1cyclin B.tsv'),
    os.path.join(data_dir_path, 'Thymidine kinase, mitochondrial.tsv'),
    os.path.join(data_dir_path, 'Stem cell growth factor receptor.tsv'),
    os.path.join(data_dir_path, 'Abl.tsv'),
    os.path.join(data_dir_path, 'Phosphoglycerate kinase.tsv'),
    os.path.join(data_dir_path, 'Tyrosine-protein kinase BRK.tsv'),
    os.path.join(data_dir_path, 'Serinethreonine-protein kinase mTOR.tsv'),
    os.path.join(data_dir_path, 'Akt3.tsv'),
    os.path.join(data_dir_path, 'PI3-kinase p110-gamma subunit.tsv')
]
print(len(tsv_file_paths))
    
# 빈 데이터프레임 초기화
merged_df = pd.DataFrame()

# 각 파일을 읽어와 병합
for file_path in tsv_file_paths:
    if os.path.exists(file_path):
        df = pd.read_csv(file_path, sep='\t', low_memory=False)
        merged_df = pd.concat([merged_df, df], ignore_index=True)
    else:
        print(f"File not found: {file_path}")

# 결과 확인
print("Merged DataFrame shape:", merged_df.shape)
print(merged_df.head())
# Out:
# 87
# File not found: train_data/original_data/Epidermal growth factor receptor erbB1.tsv
# Merged DataFrame shape: (164917, 47)
#   Molecule ChEMBL ID Molecule Name  Molecule Max Phase  Molecular Weight  \
# 0       CHEMBL597177           NaN                 NaN            292.29
# 1      CHEMBL3687191           NaN                 NaN            453.59
# 2      CHEMBL3128229           NaN                 NaN            527.43
# 3      CHEMBL3128222           NaN                 NaN            502.58
# 4      CHEMBL3128221           NaN                 NaN            563.48
#
#    #RO5 Violations  AlogP Compound Key  \
# 0              0.0   3.61           37
# 1              0.0   2.35   BDBM144321
# 2              2.0   5.70           8b
# 3              1.0   4.62          10c
# 4              2.0   5.24          10b
#
#                                               Smiles Standard Type  \
# 0        Nc1ccc2c(c1)/C(=C\c1ccc(-c3ccoc3)o1)C(=O)N2          IC50
# ...

# %%
output_file_path = os.path.join(data_dir_path, '../merged_data.csv')
merged_df.to_csv(output_file_path, index=False)

print(f"Merged data saved to {output_file_path}")
# Out:
# Merged data saved to train_data/original_data/../merged_data.csv
