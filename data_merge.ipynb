# %%
import pandas as pd
import os
import numpy as np

# %%
data_dir_path = os.path.join('train_data/original_data')

tsv_file_path1 = os.path.join(data_dir_path, 'Abl.tsv')
tsv_file_path2 = os.path.join(data_dir_path, 'Akt.tsv')
tsv_file_path3 = os.path.join(data_dir_path, 'Akt2.tsv')
tsv_file_path4 = os.path.join(data_dir_path, 'Akt3.tsv')
tsv_file_path5 = os.path.join(data_dir_path, 'ALK.tsv')
tsv_file_path6 = os.path.join(data_dir_path, 'ATM.tsv')
tsv_file_path7 = os.path.join(data_dir_path, 'ATP-dependent Clp protease proteolytic subunit.tsv')
tsv_file_path8 = os.path.join(data_dir_path, 'b-Raf.tsv')
tsv_file_path9 = os.path.join(data_dir_path, 'b-Raf2.tsv')
tsv_file_path10 = os.path.join(data_dir_path, 'Casein kinase I delta.tsv')
tsv_file_path11 = os.path.join(data_dir_path, 'Casein kinase I epsilon.tsv')
tsv_file_path12 = os.path.join(data_dir_path, 'CDKs-1.tsv')
tsv_file_path13 = os.path.join(data_dir_path, 'CDKs-2.tsv')
tsv_file_path14 = os.path.join(data_dir_path, 'CDKs-5.tsv')
tsv_file_path15 = os.path.join(data_dir_path, 'CDKs-7.tsv')
tsv_file_path16 = os.path.join(data_dir_path, 'CDKs-9.tsv')
tsv_file_path17 = os.path.join(data_dir_path, 'Choline kinase alpha.tsv')
tsv_file_path18 = os.path.join(data_dir_path, 'Cyclin-dependent kinase 1cyclin B.tsv')
tsv_file_path19 = os.path.join(data_dir_path, 'Cyclin-dependent kinase 1cyclin B1.tsv')
tsv_file_path20 = os.path.join(data_dir_path, 'Fibroblast growth factor receptor 4.tsv')
tsv_file_path21 = os.path.join(data_dir_path, 'Fibroblast growth factor receptor.tsv')
tsv_file_path22 = os.path.join(data_dir_path, 'Interleukin-1 receptor-associated kinase 1.tsv')
tsv_file_path23 = os.path.join(data_dir_path, 'Interleukin-1 receptor-associated kinase 3.tsv')
tsv_file_path24 = os.path.join(data_dir_path, 'Interleukin-1 receptor-associated kinase 4.tsv')
tsv_file_path25 = os.path.join(data_dir_path, 'JAK.tsv')
tsv_file_path26 = os.path.join(data_dir_path, 'JAK2.tsv')
tsv_file_path27 = os.path.join(data_dir_path, 'Rho kinase.tsv')
tsv_file_path28 = os.path.join(data_dir_path, 'ROCK2.tsv')
tsv_file_path29 = os.path.join(data_dir_path, 'Serinethreonine-protein kinase B-raf.tsv')
tsv_file_path30 = os.path.join(data_dir_path, 'Serinethreonine-protein kinase Chk1.tsv')
tsv_file_path31 = os.path.join(data_dir_path, 'Serinethreonine-protein kinase MST2.tsv')
tsv_file_path32 = os.path.join(data_dir_path, 'Signal transducer and activator of transcription 3.tsv')
tsv_file_path33 = os.path.join(data_dir_path, 'Tankyrase 12.tsv')
tsv_file_path34 = os.path.join(data_dir_path, 'Tankyrase-2.tsv')
tsv_file_path35 = os.path.join(data_dir_path, 'Thymidine kinase, cytosolic.tsv')
tsv_file_path36 = os.path.join(data_dir_path, 'Thymidine kinase, mitochondrial.tsv')
tsv_file_path37 = os.path.join(data_dir_path, 'Thymidine kinase.tsv')
tsv_file_path38 = os.path.join(data_dir_path, 'Vascular endothelial growth factor receptor.tsv')
tsv_file_path39 = os.path.join(data_dir_path, 'Vascular endothelial growth factor receptor 2.tsv')


csv_file_path = os.path.join(data_dir_path, 'train.csv')


tsv_data1 = pd.read_csv(tsv_file_path1, delimiter='\t')
tsv_data2 = pd.read_csv(tsv_file_path2, delimiter='\t')
tsv_data3 = pd.read_csv(tsv_file_path3, delimiter='\t')
tsv_data4 = pd.read_csv(tsv_file_path4, delimiter='\t')
tsv_data5 = pd.read_csv(tsv_file_path5, delimiter='\t')
tsv_data6 = pd.read_csv(tsv_file_path6, delimiter='\t')
tsv_data7 = pd.read_csv(tsv_file_path7, delimiter='\t')
tsv_data8 = pd.read_csv(tsv_file_path8, delimiter='\t')
tsv_data9 = pd.read_csv(tsv_file_path9, delimiter='\t')
tsv_data10 = pd.read_csv(tsv_file_path10, delimiter='\t')
tsv_data11 = pd.read_csv(tsv_file_path11, delimiter='\t')
tsv_data12 = pd.read_csv(tsv_file_path12, delimiter='\t')
tsv_data13 = pd.read_csv(tsv_file_path13, delimiter='\t')
tsv_data14 = pd.read_csv(tsv_file_path14, delimiter='\t')
tsv_data15 = pd.read_csv(tsv_file_path15, delimiter='\t')
tsv_data16 = pd.read_csv(tsv_file_path16, delimiter='\t')
tsv_data17 = pd.read_csv(tsv_file_path17, delimiter='\t')
tsv_data18 = pd.read_csv(tsv_file_path18, delimiter='\t')
tsv_data19 = pd.read_csv(tsv_file_path19, delimiter='\t')
tsv_data20 = pd.read_csv(tsv_file_path20, delimiter='\t')
tsv_data21 = pd.read_csv(tsv_file_path21, delimiter='\t')
tsv_data22 = pd.read_csv(tsv_file_path22, delimiter='\t')
tsv_data23 = pd.read_csv(tsv_file_path23, delimiter='\t')
tsv_data24 = pd.read_csv(tsv_file_path24, delimiter='\t')
tsv_data25 = pd.read_csv(tsv_file_path25, delimiter='\t')
tsv_data26 = pd.read_csv(tsv_file_path26, delimiter='\t')
tsv_data27 = pd.read_csv(tsv_file_path27, delimiter='\t')
tsv_data28 = pd.read_csv(tsv_file_path28, delimiter='\t')
tsv_data29 = pd.read_csv(tsv_file_path29, delimiter='\t')
tsv_data30 = pd.read_csv(tsv_file_path30, delimiter='\t')
tsv_data31 = pd.read_csv(tsv_file_path31, delimiter='\t')
tsv_data32 = pd.read_csv(tsv_file_path32, delimiter='\t')
tsv_data33 = pd.read_csv(tsv_file_path33, delimiter='\t')
tsv_data34 = pd.read_csv(tsv_file_path34, delimiter='\t')
tsv_data35 = pd.read_csv(tsv_file_path35, delimiter='\t')
tsv_data36 = pd.read_csv(tsv_file_path36, delimiter='\t')
tsv_data37 = pd.read_csv(tsv_file_path37, delimiter='\t')
tsv_data38 = pd.read_csv(tsv_file_path38, delimiter='\t')
tsv_data39 = pd.read_csv(tsv_file_path39, delimiter='\t')

# CSV 데이터 읽기
csv_data = pd.read_csv(csv_file_path)

# 데이터프레임 형태 출력
print(f"Abl.tsv: {tsv_data1.shape}")
print(f"Akt.tsv: {tsv_data2.shape}")
print(f"Akt2.tsv: {tsv_data3.shape}")
print(f"Akt3.tsv: {tsv_data4.shape}")
print(f"ALK.tsv: {tsv_data5.shape}")
print(f"ATM.tsv: {tsv_data6.shape}")
print(f"ATP-dependent Clp protease proteolytic subunit.tsv: {tsv_data7.shape}")
print(f"b-Raf.tsv: {tsv_data8.shape}")
print(f"b-Raf2.tsv: {tsv_data9.shape}")
print(f"Casein kinase I delta.tsv: {tsv_data10.shape}")
print(f"Casein kinase I epsilon.tsv: {tsv_data11.shape}")
print(f"CDKs-1.tsv: {tsv_data12.shape}")
print(f"CDKs-2.tsv: {tsv_data13.shape}")
print(f"CDKs-5.tsv: {tsv_data14.shape}")
print(f"CDKs-7.tsv: {tsv_data15.shape}")
print(f"CDKs-9.tsv: {tsv_data16.shape}")
print(f"Choline kinase alpha.tsv: {tsv_data17.shape}")
print(f"Cyclin-dependent kinase 1cyclin B.tsv: {tsv_data18.shape}")
print(f"Cyclin-dependent kinase 1cyclin B1.tsv: {tsv_data19.shape}")
print(f"Fibroblast growth factor receptor 4.tsv: {tsv_data20.shape}")
print(f"Fibroblast growth factor receptor.tsv: {tsv_data21.shape}")
print(f"Interleukin-1 receptor-associated kinase 1.tsv: {tsv_data22.shape}")
print(f"Interleukin-1 receptor-associated kinase 3.tsv: {tsv_data23.shape}")
print(f"Interleukin-1 receptor-associated kinase 4.tsv: {tsv_data24.shape}")
print(f"JAK.tsv: {tsv_data25.shape}")
print(f"JAK2.tsv: {tsv_data26.shape}")
print(f"Rho kinase.tsv: {tsv_data27.shape}")
print(f"ROCK2.tsv: {tsv_data28.shape}")
print(f"Serinethreonine-protein kinase B-raf.tsv: {tsv_data29.shape}")
print(f"Serinethreonine-protein kinase Chk1.tsv: {tsv_data30.shape}")
print(f"Serinethreonine-protein kinase MST2.tsv: {tsv_data31.shape}")
print(f"Signal transducer and activator of transcription 3.tsv: {tsv_data32.shape}")
print(f"Tankyrase 12.tsv: {tsv_data33.shape}")
print(f"Tankyrase-2.tsv: {tsv_data34.shape}")
print(f"Thymidine kinase, cytosolic.tsv: {tsv_data35.shape}")
print(f"Thymidine kinase, mitochondrial.tsv: {tsv_data36.shape}")
print(f"Thymidine kinase.tsv: {tsv_data37.shape}")
print(f"Vascular endothelial growth factor receptor.tsv: {tsv_data38.shape}")
print(f"Vascular endothelial growth factor receptor 2.tsv: {tsv_data39.shape}")
print(f"train.csv: {csv_data.shape}")
# Out:
# Abl.tsv: (3151, 47)
# Akt.tsv: (4269, 47)
# Akt2.tsv: (1169, 47)
# Akt3.tsv: (447, 47)
# ALK.tsv: (3520, 47)
# ATM.tsv: (617, 47)
# ATP-dependent Clp protease proteolytic subunit.tsv: (107, 47)
# b-Raf.tsv: (6962, 47)
# b-Raf2.tsv: (80, 47)
# Casein kinase I delta.tsv: (75, 47)
# Casein kinase I epsilon.tsv: (589, 47)
# CDKs-1.tsv: (1752, 47)
# CDKs-2.tsv: (2952, 47)
# CDKs-5.tsv: (420, 47)
# CDKs-7.tsv: (389, 47)
# CDKs-9.tsv: (1252, 47)
# Choline kinase alpha.tsv: (212, 47)
# Cyclin-dependent kinase 1cyclin B.tsv: (735, 47)
# Cyclin-dependent kinase 1cyclin B1.tsv: (1011, 47)
# Fibroblast growth factor receptor 4.tsv: (1752, 47)
# Fibroblast growth factor receptor.tsv: (260, 47)
# Interleukin-1 receptor-associated kinase 1.tsv: (141, 47)
# Interleukin-1 receptor-associated kinase 3.tsv: (31, 47)
# Interleukin-1 receptor-associated kinase 4.tsv: (2993, 47)
# JAK.tsv: (4766, 47)
# JAK2.tsv: (118, 47)
# Rho kinase.tsv: (92, 47)
# ROCK2.tsv: (2811, 47)
# ...

# %%
tsv_file_paths = [
    os.path.join(data_dir_path, 'Abl.tsv'),
    os.path.join(data_dir_path, 'Akt.tsv'),
    os.path.join(data_dir_path, 'Akt2.tsv'),
    os.path.join(data_dir_path, 'Akt3.tsv'),
    os.path.join(data_dir_path, 'ALK.tsv'),
    os.path.join(data_dir_path, 'ATM.tsv'),
    os.path.join(data_dir_path, 'b-Raf.tsv'),
    os.path.join(data_dir_path, 'b-Raf2.tsv'),
    os.path.join(data_dir_path, 'CDKs-1.tsv'),
    os.path.join(data_dir_path, 'CDKs-2.tsv'),
    os.path.join(data_dir_path, 'CDKs-5.tsv'),
    os.path.join(data_dir_path, 'CDKs-7.tsv'),
    os.path.join(data_dir_path, 'CDKs-9.tsv'),
    os.path.join(data_dir_path, 'Interleukin-1 receptor-associated kinase 1.tsv'),
    os.path.join(data_dir_path, 'Interleukin-1 receptor-associated kinase 3.tsv'),
    os.path.join(data_dir_path, 'Interleukin-1 receptor-associated kinase 4.tsv'),
    os.path.join(data_dir_path, 'JAK.tsv'),
    os.path.join(data_dir_path, 'JAK2.tsv'),
    os.path.join(data_dir_path, 'Rho kinase.tsv'),
    os.path.join(data_dir_path, 'ROCK2.tsv'),
    os.path.join(data_dir_path, 'Serinethreonine-protein kinase MST2.tsv'),
    os.path.join(data_dir_path, 'Thymidine kinase, cytosolic.tsv'),
    os.path.join(data_dir_path, 'Thymidine kinase, mitochondrial.tsv'),
    os.path.join(data_dir_path, 'Thymidine kinase.tsv'),
    os.path.join(data_dir_path, 'Vascular endothelial growth factor receptor.tsv'),
    os.path.join(data_dir_path, 'Vascular endothelial growth factor receptor 2.tsv'),
    os.path.join(data_dir_path, 'ATP-dependent Clp protease proteolytic subunit.tsv'),
    os.path.join(data_dir_path, 'Casein kinase I delta.tsv'),
    os.path.join(data_dir_path, 'Casein kinase I epsilon.tsv'),
    os.path.join(data_dir_path, 'Choline kinase alpha.tsv'),
    os.path.join(data_dir_path, 'Cyclin-dependent kinase 1cyclin B.tsv'),
    os.path.join(data_dir_path, 'Cyclin-dependent kinase 1cyclin B1.tsv'),
    os.path.join(data_dir_path, 'Fibroblast growth factor receptor 4.tsv'),
    os.path.join(data_dir_path, 'Fibroblast growth factor receptor.tsv'),
    os.path.join(data_dir_path, 'Interleukin-1 receptor-associated kinase 4.tsv'),
    os.path.join(data_dir_path, 'Serinethreonine-protein kinase B-raf.tsv'),
    os.path.join(data_dir_path, 'Serinethreonine-protein kinase Chk1.tsv'),
    os.path.join(data_dir_path, 'Signal transducer and activator of transcription 3.tsv'),
    os.path.join(data_dir_path, 'Tankyrase 12.tsv'),
    os.path.join(data_dir_path, 'Tankyrase-2.tsv')
]

csv_columns = csv_data.columns.tolist()

# 딕셔너리로 조정된 데이터프레임 저장
adjusted_dfs = []
for path in tsv_file_paths:
    filename = os.path.basename(path).split('.')[0]  # 파일 이름만 추출
    tsv_data = pd.read_csv(path, delimiter='\t')
    
    # 필요한 모든 열이 있는지 확인하고 없는 경우 NaN으로 채움
    for col in csv_columns:
        if col not in tsv_data.columns:
            tsv_data[col] = np.nan
    
    # train.csv의 열 순서에 맞게 열 정렬
    tsv_data = tsv_data[csv_columns]
    
    adjusted_dfs.append(tsv_data)

# 모든 데이터 프레임을 하나로 합치기
merged_data = pd.concat([csv_data] + adjusted_dfs, ignore_index=True)

print("Merged DataFrame shape:", merged_data.shape)
print(merged_data)
# Out:
# Merged DataFrame shape: (74411, 15)
#       Molecule ChEMBL ID Standard Type Standard Relation  Standard Value  \
# 0          CHEMBL4443947          IC50               '='           0.022
# 1          CHEMBL4556091          IC50               '='           0.026
# 2          CHEMBL4566431          IC50               '='           0.078
# 3          CHEMBL4545898          IC50               '='           0.081
# 4          CHEMBL4448950          IC50               '='           0.099
# ...                  ...           ...               ...             ...
# 74406      CHEMBL5072185          IC50               '='           5.400
# 74407      CHEMBL3736012          IC50               '<'          60.000
# 74408      CHEMBL5275231          IC50               '='          35.000
# 74409      CHEMBL4126054          IC50               '='        6500.000
# 74410      CHEMBL3108871          IC50               '='          24.000
#
# ...

# %%
merged_data.to_csv('train_data/protein_data.csv', index=False)
